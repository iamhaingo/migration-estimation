# %%
# read parquet
import geopandas as gpd

gdf = gpd.read_parquet("data/raw/gd_disasters.parquet")

# %%
gdf
# Out:
#       ISO3 Start date   End date  Total figures                    geometry
# 0      AB9 2023-01-01 2023-04-30           1045    POINT (28.46257 9.46809)
# 1      AB9 2023-01-01 2023-12-31           4409    POINT (28.46257 9.46809)
# 2      AB9 2024-08-01 2024-08-31           1650    POINT (28.46257 9.46809)
# 3      AB9 2024-09-01 2024-10-16            990    POINT (28.46257 9.46809)
# 4      AB9 2024-09-01 2024-10-16          11930    POINT (28.46257 9.46809)
# ...    ...        ...        ...            ...                         ...
# 12791  ZWE 2024-10-23 2024-10-23             25  POINT (29.94154 -21.81297)
# 12792  ZWE 2024-11-03 2024-11-03              8  POINT (28.46292 -20.97013)
# 12793  ZWE 2024-11-11 2024-11-17             40  POINT (29.14799 -18.99393)
# 12794  ZWE 2024-11-18 2024-11-18             24  POINT (28.64563 -19.03068)
# 12795  ZWE 2024-11-18 2024-11-18            121  POINT (30.56938 -20.50531)
#
# [12796 rows x 5 columns]
